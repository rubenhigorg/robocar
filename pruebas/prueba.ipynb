# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt
from line import Line
from processor import ImageProcessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import numpy as np
#       4 from matplotlib import pyplot as plt
# ----> 5 from line import Line
#       6 from processor import ImageProcessor
#
# ModuleNotFoundError: No module named 'line'

# %% [markdown]
# Cargamos archivo de imagen
# You are facing this issue since you are reading the image with opencv and opencv reads and displays an image as BGR format instead of RGB color format. Whereas matplotlib uses RGB color format to display image

# %%
# Ruta de la imagen
ruta_imagen = "/home/lab/robocar/pruebas/computer_vision/coche.jpg"
# Cargar la imagen en color
frame = cv2.imread(ruta_imagen)
# Convertir a RGB para mostrar
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %% [markdown]
# Mostrar Imagen

# %%
plt.imshow(frame_rgb)
plt.show()

# %% [markdown]
# Imageprocessor

# %%
processor = ImageProcessor((480, 320), 20)
out = processor.process(frame_rgb)
plt.imshow(out)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 processor = ImageProcessor((480, 320), 20)
#       2 out = processor.process(frame_rgb)
#       3 plt.imshow(out)
#
# NameError: name 'ImageProcessor' is not defined
